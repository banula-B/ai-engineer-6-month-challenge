# %%
import pandas as pd

# %%
data = pd.read_csv("../data sets/pokemon.csv")

# %% [markdown]
# Let's give a chance to users to find pokemons details

# %%
pokemon=input("Enter Pokemon Name: ")

try:
    print(data.loc[pokemon])
except KeyError:
    print(f"{pokemon} not Found!")
# Out:
# banula not Found!
